# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
#import data
country_scores = pd.read_csv("./data/country_scores.csv")
country_incomes = pd.read_csv("./data/WDI_data.csv")
country_incomes
# Out:
#                                          Country Name Country Code  \
# 0                                         Afghanistan          AFG
# 1                                         Afghanistan          AFG
# 2                                         Afghanistan          AFG
# 3                                             Albania          ALB
# 4                                             Albania          ALB
# ..                                                ...          ...
# 792                                               NaN          NaN
# 793                                               NaN          NaN
# 794                                               NaN          NaN
# 795  Data from database: World Development Indicators          NaN
# 796                          Last Updated: 05/21/2018          NaN
#
#                                            Series Name        Series Code  \
# 0    GDP per capita, PPP (constant 2011 internation...  NY.GDP.PCAP.PP.KD
# 1                   School enrollment, primary (% net)        SE.PRM.NENR
# 2                 School enrollment, primary (% gross)        SE.PRM.ENRR
# 3    GDP per capita, PPP (constant 2011 internation...  NY.GDP.PCAP.PP.KD
# 4                   School enrollment, primary (% net)        SE.PRM.NENR
# ..                                                 ...                ...
# 792                                                NaN                NaN
# 793                                                NaN                NaN
# 794                                                NaN                NaN
# 795                                                NaN                NaN
# 796                                                NaN                NaN
#
#         2015 [YR2015]
# 0    1809.01648820483
# 1                  ..
# 2    107.225357055664
# 3    10971.2925173789
# 4    95.1996002197266
# ..                ...
# 792               NaN
# 793               NaN
# 794               NaN
# 795               NaN
# 796               NaN
#
# [797 rows x 5 columns]

# %%
country_incomes = country_incomes.dropna()
country_incomes = country_incomes[country_incomes["2015 [YR2015]"] != '..']
country_incomes = country_incomes[country_incomes["Series Name"] == country_incomes["Series Name"].iloc[0]]

# %%
country_incomes
# Out:
#             Country Name Country Code  \
# 0            Afghanistan          AFG
# 3                Albania          ALB
# 6                Algeria          DZA
# 15                Angola          AGO
# 18   Antigua and Barbuda          ATG
# ..                   ...          ...
# 777   West Bank and Gaza          PSE
# 780                World          WLD
# 783          Yemen, Rep.          YEM
# 786               Zambia          ZMB
# 789             Zimbabwe          ZWE
#
#                                            Series Name        Series Code  \
# 0    GDP per capita, PPP (constant 2011 internation...  NY.GDP.PCAP.PP.KD
# 3    GDP per capita, PPP (constant 2011 internation...  NY.GDP.PCAP.PP.KD
# 6    GDP per capita, PPP (constant 2011 internation...  NY.GDP.PCAP.PP.KD
# 15   GDP per capita, PPP (constant 2011 internation...  NY.GDP.PCAP.PP.KD
# 18   GDP per capita, PPP (constant 2011 internation...  NY.GDP.PCAP.PP.KD
# ..                                                 ...                ...
# 777  GDP per capita, PPP (constant 2011 internation...  NY.GDP.PCAP.PP.KD
# 780  GDP per capita, PPP (constant 2011 internation...  NY.GDP.PCAP.PP.KD
# 783  GDP per capita, PPP (constant 2011 internation...  NY.GDP.PCAP.PP.KD
# 786  GDP per capita, PPP (constant 2011 internation...  NY.GDP.PCAP.PP.KD
# 789  GDP per capita, PPP (constant 2011 internation...  NY.GDP.PCAP.PP.KD
#
#         2015 [YR2015]
# 0    1809.01648820483
# 3    10971.2925173789
# 6     13724.723852895
# 15   6231.06799206401
# 18   20154.9474879241
# ..                ...
# 777  4339.10369305975
# 780   14766.537605517
# 783  2641.04582911357
# 786  3627.20204093772
# 789  1912.28026439598
#
# [234 rows x 5 columns]

# %%
country_scores
# Out:
#           Country Country Code  \
# 0          U.A.E.          ARE
# 1       Argentina          ARG
# 2         Armenia          ARM
# 3       Australia          AUS
# 4         Austria          AUT
# ..            ...          ...
# 73         Turkey          TUR
# 74        Uruguay          URY
# 75  United States          USA
# 76          Yemen          YEM
# 77   South Africa          ZAF
#
#     Percent Above Math Benchmark (400 on TIMSS Scale)  \
# 0                                                64.0
# 1                                                51.0
# 2                                                72.0
# 3                                                90.0
# 4                                                95.0
# ..                                                ...
# 73                                               77.0
# 74                                               57.0
# 75                                               96.0
# 76                                                9.0
# 77                                                NaN
#
#     Percent Above Reading Benchmark (400 on PIRLS Scale)  \
# 0                                                64.0
# 1                                                66.0
# 2                                                 NaN
# 3                                                93.0
# 4                                                97.0
# ..                                                ...
# 73                                                NaN
# 74                                               70.0
# 75                                               98.0
# 76                                                NaN
# 77                                               24.0
#
#     Median Math Score (TIMSS Scale, 4th Grade)  \
# 0                                        437.0
# 1                                        407.0
# 2                                        454.0
# 3                                        520.0
# 4                                        511.0
# ..                                         ...
# 73                                       477.0
# 74                                       425.0
# 75                                       544.0
# 76                                       243.0
# 77                                         NaN
#
#     Median Reading Score (PIRLS Scale, 4th Grade)
# 0                                           440.0
# 1                                           431.0
# 2                                             NaN
# 3                                           534.0
# 4                                           533.0
# ..                                            ...
# 73                                            NaN
# 74                                          450.0
# 75                                          560.0
# 76                                            NaN
# 77                                          323.0
#
# [78 rows x 6 columns]

# %%
data = country_scores.merge(country_incomes[["Country Code","2015 [YR2015]"]],how="inner",on="Country Code")
data = data.drop(columns=["Percent Above Math Benchmark (400 on TIMSS Scale)","Percent Above Reading Benchmark (400 on PIRLS Scale)"])

# %%
data = data.dropna()
data.dtypes
# Out:
# Country                                           object
# Country Code                                      object
# Median Math Score (TIMSS Scale, 4th Grade)       float64
# Median Reading Score (PIRLS Scale, 4th Grade)    float64
# 2015 [YR2015]                                     object
# dtype: object

# %%
data["2015 [YR2015]"] = data["2015 [YR2015]"].astype(float,errors="raise")
data.dtypes
# Out:
# Country                                           object
# Country Code                                      object
# Median Math Score (TIMSS Scale, 4th Grade)       float64
# Median Reading Score (PIRLS Scale, 4th Grade)    float64
# 2015 [YR2015]                                    float64
# dtype: object

# %%
plt.figure(figsize=(12,20))
plt.style.use("ggplot")
plt.subplots_adjust(hspace=.1)
plt.subplot(2,1,1)
plt.scatter(data["2015 [YR2015]"],data["Median Math Score (TIMSS Scale, 4th Grade)"],c="k")
plt.xlabel("log2 GDP per capita (PPP) in 2015")
plt.ylabel("TIMSS")
plt.subplot(2,1,2)
plt.scatter(data["2015 [YR2015]"],data["Median Reading Score (PIRLS Scale, 4th Grade)"],c="k")
plt.xlabel("log2 GDP per capita (PPP) in 2015")
plt.ylabel("PIRLS")
# Out:
# Text(0, 0.5, 'PIRLS')

# %%
plt.figure(figsize=(12,20))
plt.style.use("ggplot")
plt.subplots_adjust(hspace=.1)
plt.subplot(2,1,1)
plt.scatter(np.log2(data["2015 [YR2015]"]),data["Median Math Score (TIMSS Scale, 4th Grade)"],c="k")
plt.xlabel("log2 GDP per capita (PPP) in 2015")
plt.ylabel("TIMSS")
plt.subplot(2,1,2)
plt.scatter(np.log2(data["2015 [YR2015]"]),data["Median Reading Score (PIRLS Scale, 4th Grade)"],c="k")
plt.xlabel("log2 GDP per capita (PPP) in 2015")
plt.ylabel("PIRLS")
# Out:
# Text(0, 0.5, 'PIRLS')

# %%
data.rename(columns={"Median Math Score (TIMSS Scale, 4th Grade)":"TIMSS",
                     "Median Reading Score (PIRLS Scale, 4th Grade)":"PIRLS",
                     "2015 [YR2015]":"GDP"},inplace=True)
data
# Out:
#           Country Country Code  TIMSS  PIRLS           GDP
# 0          U.A.E.          ARE  437.0  440.0  65975.375547
# 1       Argentina          ARG  407.0  431.0  19101.297392
# 3       Australia          AUS  520.0  534.0  43719.502165
# 4         Austria          AUT  511.0  533.0  44353.875214
# 5      Azerbaijan          AZE  465.0  467.0  16698.863653
# ..            ...          ...    ...    ...           ...
# 67         Sweden          SWE  507.0  545.0  45679.277997
# 68           Chad          TCD  346.0  341.0   2047.637179
# 69           Togo          TGO  406.0  374.0   1349.371568
# 74        Uruguay          URY  425.0  450.0  19831.445894
# 75  United States          USA  544.0  560.0  53029.293361
#
# [61 rows x 5 columns]

# %%
#Check for linear correlation on log GDP and TIMSS
linear_mod_TIMSS = smf.ols("TIMSS ~ np.log2(GDP)",data=data)
linear_res_TIMSS = linear_mod_TIMSS.fit()
linear_res_TIMSS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  TIMSS   R-squared:                       0.338
# Model:                            OLS   Adj. R-squared:                  0.327
# Method:                 Least Squares   F-statistic:                     30.19
# Date:                Wed, 20 Apr 2022   Prob (F-statistic):           8.77e-07
# Time:                        16:04:59   Log-Likelihood:                -337.79
# No. Observations:                  61   AIC:                             679.6
# Df Residuals:                      59   BIC:                             683.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       86.5978     66.508      1.302      0.198     -46.485     219.680
# np.log2(GDP)    25.8861      4.711      5.494      0.000      16.459      35.314
# ==============================================================================
# Omnibus:                        1.183   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.554   Jarque-Bera (JB):                1.116
# Skew:                          -0.316   Prob(JB):                        0.572
# Kurtosis:                       2.802   Cond. No.                         118.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = np.log2(data["GDP"])
y = linear_res_TIMSS.params["Intercept"] + linear_res_TIMSS.params["np.log2(GDP)"]*x
plt.figure(figsize=(12,10))
plt.style.use("ggplot")
plt.scatter(np.log2(data["GDP"]),data["TIMSS"],c="k")
plt.plot(x,y,c="r",linewidth=2)
plt.xlabel("log2 GDP per capita (PPP) in 2015")
plt.ylabel("TIMSS")
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# Text(0, 0.5, 'TIMSS')

# %%
#check for linear correlation on log GDP and PIRLS
linear_mod_PIRLS = smf.ols("PIRLS ~ np.log2(GDP)",data=data)
linear_res_PIRLS = linear_mod_PIRLS.fit()
linear_res_PIRLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  PIRLS   R-squared:                       0.471
# Model:                            OLS   Adj. R-squared:                  0.462
# Method:                 Least Squares   F-statistic:                     52.59
# Date:                Wed, 20 Apr 2022   Prob (F-statistic):           1.01e-09
# Time:                        16:04:59   Log-Likelihood:                -328.75
# No. Observations:                  61   AIC:                             661.5
# Df Residuals:                      59   BIC:                             665.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       56.2165     57.346      0.980      0.331     -58.532     170.965
# np.log2(GDP)    29.4590      4.062      7.252      0.000      21.330      37.588
# ==============================================================================
# Omnibus:                        8.028   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.018   Jarque-Bera (JB):                7.993
# Skew:                          -0.885   Prob(JB):                       0.0184
# Kurtosis:                       3.107   Cond. No.                         118.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = np.log2(data["GDP"])
y = linear_res_PIRLS.params["Intercept"] + linear_res_PIRLS.params["np.log2(GDP)"]*x
plt.figure(figsize=(12,10))
plt.style.use("ggplot")
plt.scatter(np.log2(data["GDP"]),data["PIRLS"],c="k")
plt.plot(x,y,c="r",linewidth=2)
plt.xlabel("log2 GDP per capita (PPP) in 2015")
plt.ylabel("PIRLS")
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# Text(0, 0.5, 'PIRLS')

# %%
data
# Out:
#           Country Country Code  TIMSS  PIRLS           GDP
# 0          U.A.E.          ARE  437.0  440.0  65975.375547
# 1       Argentina          ARG  407.0  431.0  19101.297392
# 3       Australia          AUS  520.0  534.0  43719.502165
# 4         Austria          AUT  511.0  533.0  44353.875214
# 5      Azerbaijan          AZE  465.0  467.0  16698.863653
# ..            ...          ...    ...    ...           ...
# 67         Sweden          SWE  507.0  545.0  45679.277997
# 68           Chad          TCD  346.0  341.0   2047.637179
# 69           Togo          TGO  406.0  374.0   1349.371568
# 74        Uruguay          URY  425.0  450.0  19831.445894
# 75  United States          USA  544.0  560.0  53029.293361
#
# [61 rows x 5 columns]

# %%
age_of_education = pd.read_stata("./data/BL2013_MF1599_v2.2.dta")
age_of_education_2010 = age_of_education[age_of_education.year == 2010.0]
age_of_education_2010 = age_of_education_2010.rename(columns={"country":"Country"})
age_of_education_2010
# Out:
#       BLcode                                     Country    year sex  agefrom  \
# 935     90.0                                       Japan  2010.0  MF     15.0
# 1728   315.0                                    Maldives  2010.0  MF     15.0
# 441     46.0                                      Zambia  2010.0  MF     15.0
# 181     22.0                                     Lesotho  2010.0  MF     15.0
# 116     15.0                                       Gabon  2010.0  MF     15.0
# 649     67.0                                   Argentina  2010.0  MF     15.0
# 1871   331.0                                    Slovenia  2010.0  MF     15.0
# 454     47.0                                    Zimbabwe  2010.0  MF     15.0
# 1611   155.0                                        Cuba  2010.0  MF     15.0
# 51       6.0                                     Burundi  2010.0  MF     15.0
# 1793   322.0                                     Croatia  2010.0  MF     15.0
# 1884   342.0  China, Macao Special Administrative Region  2010.0  MF     15.0
# 1143   107.0                                     Austria  2010.0  MF     15.0
# 1598   154.0                          Russian Federation  2010.0  MF     15.0
# 1507   141.0                                     Namibia  2010.0  MF     15.0
# 1819   324.0                                      Latvia  2010.0  MF     15.0
# 1091   103.0                                      Taiwan  2010.0  MF     15.0
# 1338   123.0                                      Poland  2010.0  MF     15.0
# 636   26.758747  13.182642    5.957662    5.610994    1.613986  249660.0
# 1013   4.429484   5.023350    2.663054    2.157640    0.202656  112500.0
# 519    3.916702   7.770356    6.017601    1.563616    0.189140    5076.0
# 558    1.925154   6.189973    4.494114    1.586605    0.109254    5087.0
# 272    0.260846   1.926388    1.579990    0.331914    0.014484   12336.0
# 1767   3.742130  10.302694    3.965003    6.122519    0.215172    4507.0
# 103    6.649380   7.149272    3.842247    2.939079    0.367946   54733.0
# 259    5.350593   4.960254    2.806826    1.859103    0.294325   23834.0
# 1299  10.524044  10.518352    5.824757    4.225960    0.467635     343.0
# 1702   8.996319  10.711409    3.950671    6.261653    0.499084    3961.0
# 77     0.825947   3.759105    2.603630    1.107464    0.048011    2518.0
# 987    5.806347  10.444671    5.374739    4.581790    0.488142   19391.0
#
#      WBcode                      region_code
# 935     JPN               Advanced Economies
# 1728    MDV                       South Asia
# 441     ZMB               Sub-Saharan Africa
# 181     LSO               Sub-Saharan Africa
# 116     GAB               Sub-Saharan Africa
# 649     ARG  Latin America and the Caribbean
# 1871    SVN          Europe and Central Asia
# 454     ZWE               Sub-Saharan Africa
# 1611    CUB  Latin America and the Caribbean
# 51      BDI               Sub-Saharan Africa
# 1793    HRV          Europe and Central Asia
# 1884    MAC        East Asia and the Pacific
# 1143    AUT               Advanced Economies
# 1598    RUS          Europe and Central Asia
# 1507    NAM               Sub-Saharan Africa
# 1819    LVA          Europe and Central Asia
# 1091    TWN        East Asia and the Pacific
# 1338    POL          Europe and Central Asia
# 883     IDN        East Asia and the Pacific
# 1559    BGR          Europe and Central Asia
# 415     UGA               Sub-Saharan Africa
# 38      BWA               Sub-Saharan Africa
# 1104    THA        East Asia and the Pacific
# 1494    LBY     Middle East and North Africa
# 1468    PNG        East Asia and the Pacific
# 1663    ARM          Europe and Central Asia
# 298     RWA               Sub-Saharan Africa
# 870     IND                       South Asia
# 636     USA               Advanced Economies
# 1013    PAK                       South Asia
# 519     SLV  Latin America and the Caribbean
# 558     HND  Latin America and the Caribbean
# 272     MOZ               Sub-Saharan Africa
# 1767    TJK          Europe and Central Asia
# 103     EGY     Middle East and North Africa
# 259     MAR     Middle East and North Africa
# 1299    MLT     Middle East and North Africa
# 1702    KGZ          Europe and Central Asia
# 77      CAF               Sub-Saharan Africa
# 987     MYS        East Asia and the Pacific

# %%
data_with_sch = data.merge(age_of_education_2010[["Country","yr_sch"]],how="inner",on="Country")
print(data_with_sch[data_with_sch['yr_sch'].isna()])
# Out:
# Empty DataFrame
# Columns: [Country, Country Code, TIMSS, PIRLS, GDP, yr_sch]
# Index: []

# %%
#plot GDP - education years
plt.figure(figsize=(12,10))
plt.scatter(data_with_sch["GDP"],data_with_sch["yr_sch"],c="k")
plt.xlabel("GDP")
plt.ylabel("Years Of Schooling")
# Out:
# Text(0, 0.5, 'Years Of Schooling')

# %%
#plot log2(GDP) - education years
plt.figure(figsize=(12,10))
plt.scatter(np.log2(data_with_sch["GDP"]),data_with_sch["yr_sch"],c="k")
plt.xlabel("log2_GDP")
plt.ylabel("Years Of Schooling")
# Out:
# Text(0, 0.5, 'Years Of Schooling')

# %%
#Check for linear correlation on log2_GDP and Years Of Schooling
linear_mod_ysc = smf.ols("yr_sch~np.log2(GDP)",data=data_with_sch)
linear_res_ysc = linear_mod_ysc.fit()
linear_res_ysc.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 yr_sch   R-squared:                       0.662
# Model:                            OLS   Adj. R-squared:                  0.655
# Method:                 Least Squares   F-statistic:                     90.29
# Date:                Wed, 20 Apr 2022   Prob (F-statistic):           2.01e-12
# Time:                        16:05:02   Log-Likelihood:                -89.727
# No. Observations:                  48   AIC:                             183.5
# Df Residuals:                      46   BIC:                             187.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -9.5189      1.939     -4.909      0.000     -13.422      -5.615
# np.log2(GDP)     1.3018      0.137      9.502      0.000       1.026       1.578
# ==============================================================================
# Omnibus:                       10.871   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               10.728
# Skew:                          -0.962   Prob(JB):                      0.00468
# Kurtosis:                       4.290   Cond. No.                         119.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#plot log2(GDP) - education years with linear regression line
x = np.log2(data_with_sch["GDP"])
y = linear_res_ysc.params["Intercept"] + linear_res_ysc.params["np.log2(GDP)"]*x
plt.figure(figsize=(12,10))
plt.scatter(np.log2(data_with_sch["GDP"]),data_with_sch["yr_sch"],c="k")
plt.plot(x,y,c="r",linewidth=2)
plt.xlabel("log2_GDP")
plt.ylabel("Years Of Schooling")
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# Text(0, 0.5, 'Years Of Schooling')

# %%
#Create regression models with new data for PIRLS,TIMSS
linear_mod_PIRLS = smf.ols("PIRLS ~ np.log2(GDP)",data=data_with_sch)
linear_res_PIRLS = linear_mod_PIRLS.fit()
linear_mod_TIMSS = smf.ols("TIMSS ~ np.log2(GDP)",data=data_with_sch)
linear_res_TIMSS = linear_mod_TIMSS.fit()

# %%
plt.figure(figsize=(10,20))
plt.subplot(2,1,1)
plt.scatter(linear_res_ysc.resid,linear_res_TIMSS.resid,c="k")
plt.xlabel("Years Of Scholling( Residualized)")
plt.ylabel("TIMSS (Residualized)")

plt.subplot(2,1,2)
plt.scatter(linear_res_ysc.resid,linear_res_PIRLS.resid,c="k")
plt.xlabel("Years Of Scholling( Residualized)")
plt.ylabel("PIRLS (Residualized)")
# Out:
# Text(0, 0.5, 'PIRLS (Residualized)')

# %%
resid_TIMSS = np.array(linear_res_TIMSS.resid)
resid_PIRLS = np.array(linear_res_PIRLS.resid)
resid_yr_sch = np.array(linear_res_ysc.resid)
resid_data = np.stack((resid_TIMSS,resid_PIRLS,resid_yr_sch))
resid_data = resid_data.T

residuals = pd.DataFrame(data=resid_data,
                        columns=["resid_TIMSS","resid_PIRLS","resid_yr_sch"])

# %%
#Check linear correlation between TIMSS(Residualized) and Years Of Schooling(Residualized)
linear_mod_resid_TIMSS = smf.ols(formula="resid_TIMSS ~ resid_yr_sch",data=residuals)
linear_res_resid_TIMSS = linear_mod_resid_TIMSS.fit()
linear_res_resid_TIMSS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            resid_TIMSS   R-squared:                       0.280
# Model:                            OLS   Adj. R-squared:                  0.264
# Method:                 Least Squares   F-statistic:                     17.89
# Date:                Wed, 20 Apr 2022   Prob (F-statistic):           0.000110
# Time:                        16:06:39   Log-Likelihood:                -256.20
# No. Observations:                  48   AIC:                             516.4
# Df Residuals:                      46   BIC:                             520.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept    -1.403e-13      7.420  -1.89e-14      1.000     -14.936      14.936
# resid_yr_sch    20.0069      4.730      4.230      0.000      10.487      29.527
# ==============================================================================
# Omnibus:                        5.139   Durbin-Watson:                   1.820
# Prob(Omnibus):                  0.077   Jarque-Bera (JB):                3.959
# Skew:                           0.626   Prob(JB):                        0.138
# Kurtosis:                       3.642   Cond. No.                         1.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
plt.figure(figsize=(12,10))
x = residuals.resid_yr_sch
y = linear_res_resid_TIMSS.params["Intercept"] + linear_res_resid_TIMSS.params["resid_yr_sch"] * x
plt.scatter(linear_res_ysc.resid,linear_res_TIMSS.resid,c="k")
plt.plot(x,y,c="r",linewidth=2)
plt.xlabel("Years Of Scholling( Residualized)")
plt.ylabel("TIMSS (Residualized)")
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# Text(0, 0.5, 'TIMSS (Residualized)')

# %%
#Check linear correlation between PIRLS(Residualized) and Years Of Schooling(Residualized)
linear_mod_resid_PIRLS = smf.ols("resid_PIRLS~resid_yr_sch",data=residuals)
linear_res_resid_PIRLS= linear_mod_resid_PIRLS.fit()
linear_res_resid_PIRLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            resid_PIRLS   R-squared:                       0.391
# Model:                            OLS   Adj. R-squared:                  0.377
# Method:                 Least Squares   F-statistic:                     29.49
# Date:                Wed, 20 Apr 2022   Prob (F-statistic):           2.05e-06
# Time:                        16:11:08   Log-Likelihood:                -244.26
# No. Observations:                  48   AIC:                             492.5
# Df Residuals:                      46   BIC:                             496.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept    -1.874e-13      5.787  -3.24e-14      1.000     -11.648      11.648
# resid_yr_sch    20.0289      3.688      5.430      0.000      12.605      27.453
# ==============================================================================
# Omnibus:                        1.340   Durbin-Watson:                   1.883
# Prob(Omnibus):                  0.512   Jarque-Bera (JB):                0.581
# Skew:                          -0.148   Prob(JB):                        0.748
# Kurtosis:                       3.450   Cond. No.                         1.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
plt.figure(figsize=(12,10))
x = residuals.resid_yr_sch
y = linear_res_resid_PIRLS.params["Intercept"] + linear_res_resid_PIRLS.params["resid_yr_sch"] * x
plt.scatter(linear_res_ysc.resid,linear_res_PIRLS.resid,c="k")
plt.plot(x,y,c="r",linewidth=2)
plt.xlabel("Years Of Scholling( Residualized)")
plt.ylabel("PIRLS (Residualized)")
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# Text(0, 0.5, 'PIRLS (Residualized)')
